# %% [markdown]
# # Project 2: Operational Process Analysis & Bottleneck Detection
# **Author:** Maha
#
# ## Personal Motivation
# I chose this project because many real problems in companies are not about complex algorithms,
# but about understanding how processes actually work.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Simulating a Realistic Internal Company Process
# Each row represents one process case (e.g. a service request).

# %%
process_df.head()

# %% [markdown]
# ## 3. Data Validation

# %%
process_df.isnull().sum()

# %% [markdown]
# ## 4. Descriptive Statistics

# %%
process_df[["review_days","approval_days","processing_days","total_duration_days"]].describe()

# %% [markdown]
# ## 5. Bottleneck Analysis

# %%
average_durations = process_df[["review_days","approval_days","processing_days"]].mean()
average_durations

# %% [markdown]
# ## 6. Visualization

# %%
average_durations.plot(kind="bar", title="Average Duration per Process Step")

# %% [markdown]
# ## 7. KPI Calculation

# %%
{
    "Average total duration (days)": process_df["total_duration_days"].mean(),
    "Median total duration (days)": process_df["total_duration_days"].median(),
    "Longest case duration (days)": process_df["total_duration_days"].max()
}

# %% [markdown]
# ## 8. Business Interpretation
# The processing step is the main bottleneck. Improving this step could significantly reduce total cycle time.
